# %%
import numpy as np

# %%
# Task_1

# %%
a = np.array([[1,6],
          [2,8],
          [3,11],
          [3,10],
          [1,7]])

# %%
mean_a = a.mean(axis=0)
mean_a
# Out:
# array([2. , 8.4])

# %%
# Task_2

# %%
a_centered = a - mean_a
a_centered
# Out:
# array([[-1. , -2.4],
#        [ 0. , -0.4],
#        [ 1. ,  2.6],
#        [ 1. ,  1.6],
#        [-1. , -1.4]])

# %%
# Task_3

# %%
a_centered_sp = a_centered[:,0]@a_centered[:,0]
a_centered_sp
# Out:
# 4.0

# %%
a_centered_sp/(5-1)
# Out:
# 1.0

# %%
#Task4:

# %%
m = np.cov(a.T)
m
# Out:
# array([[1. , 2. ],
#        [2. , 4.3]])

# %%
cov = m[0,0]
cov
# Out:
# 1.0
